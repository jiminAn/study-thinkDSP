# %% [markdown]
# ## 디지털신호처리 과제4
#
# 컴퓨터과학과 201810954 안지민

# %%
from __future__ import print_function, division

# %matplotlib inline

import thinkdsp
import thinkplot
import numpy as np
import math

import warnings
warnings.filterwarnings('ignore')

from IPython.html.widgets import interact, interact_manual, fixed
from IPython.html import widgets
from IPython.display import display

PI2 = 2 * math.pi

# %% [markdown]
# ### Exercise 2.3
#
# Make a square signal at 1100 Hz and make a wave that samples it
# at 10000 frames per second.  If you plot the spectrum, you can
# see that most of the harmonics are aliased.
# When you listen to the wave, can you hear the aliased harmonics?

# %% [markdown]
# ### Solution
# 아래처럼 1000Hz의 square signal을 생성하였다 이 signal은 1초에 10000번 샘플링 되었다.

# %%
square = thinkdsp.SquareSignal(1100).make_wave(duration=0.5, framerate=10000)

# %% [markdown]
# 스팩트럼은 아래와 같다.

# %%
square.make_spectrum().plot()

# %% [markdown]
# fundamental frequency와  첫 harmonic은 왼편에 있는데, 5500Hz에 있어야 할 두 번째 harmonic은 aliasing되어 4500Hz에 있다.
# 7700Hz에 있어야 할 세 번째 harmonic은 aliasing되어 2300Hz에 있다 기타등등
#
# wave를 들을 때 이러한 aliased hamonics 을 low tone으로 들을 수 있다.

# %%
square.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# 가장 눈에띄게 들은 톤은 300Hz에서이다.

# %%
thinkdsp.SinSignal(300).make_wave(duration=0.5, framerate=10000).make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
